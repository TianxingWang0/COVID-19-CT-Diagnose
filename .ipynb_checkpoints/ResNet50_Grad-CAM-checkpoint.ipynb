# %% [markdown]
# ## Load data from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from glob import glob
import numpy as np
import pandas as pd
import os
import shutil 
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras import backend as K
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import categorical_accuracy
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline

# %% [markdown]
# ## Excute below blocks only `once` to random divide train-validation sets

# %%
cov_files = glob('/content/drive/My Drive/Colab Notebooks/covid-19/cov_processed/*')
vir_files = glob('/content/drive/My Drive/Colab Notebooks/covid-19/vir_processed/*')
nor_files = glob('/content/drive/My Drive/Colab Notebooks/covid-19/nor_processed/*')
print("covid-19: ", len(cov_files))
print("viral pneumonia: ", len(vir_files))
print("normal: ", len(nor_files))
# Out:
# covid-19:  756
# viral pneumonia:  1361
# normal:  1422

# %%
cov_train = np.random.choice(cov_files, size=600, replace=False) 
vir_train = np.random.choice(vir_files, size=1200, replace=False) 
nor_train = np.random.choice(nor_files, size=1200, replace=False) 

cov_files = list(set(cov_files) - set(cov_train)) 
vir_files = list(set(vir_files) - set(vir_train)) 
nor_files = list(set(nor_files) - set(nor_train))

cov_val = np.random.choice(cov_files, size=len(cov_files), replace=False) 
vir_val = np.random.choice(vir_files, size=len(vir_files), replace=False) 
nor_val = np.random.choice(nor_files, size=len(nor_files), replace=False) 
 
print('cov datasets: ', cov_train.shape, cov_val.shape) 
print('vir datasets: ', vir_train.shape, vir_val.shape) 
print('nor datasets: ', nor_train.shape, nor_val.shape)
# Out:
# cov datasets:  (600,) (156,)
# vir datasets:  (1200,) (161,)
# nor datasets:  (1200,) (222,)

# %%
train_files = np.concatenate((cov_train, vir_train, nor_train), axis=0).tolist()
train_labels = [path.split('/')[6][0:3] for path in train_files]

validation_files = np.concatenate((cov_val, vir_val, nor_val), axis=0).tolist()
validation_labels = [path.split('/')[6][0:3] for path in validation_files]

# %%
import shutil
os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/train')

os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/train/cov')
train_cov = '/content/drive/My Drive/Colab Notebooks/covid-19/train/cov'

os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/train/vir')
train_vir = '/content/drive/My Drive/Colab Notebooks/covid-19/train/vir'

os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/train/nor')
train_nor = '/content/drive/My Drive/Colab Notebooks/covid-19/train/nor'

for i in range(len(train_files)):
    if train_labels[i] == 'cov':
        shutil.copyfile(train_files[i], os.path.join(train_cov, train_files[i].split('/')[-1]))
    elif train_labels[i] == 'nor':
        shutil.copyfile(train_files[i], os.path.join(train_nor, train_files[i].split('/')[-1]))
    else:
        shutil.copyfile(train_files[i], os.path.join(train_vir, train_files[i].split('/')[-1]))

# %%
import shutil
os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/validation')

os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/validation/cov')
validation_cov = '/content/drive/My Drive/Colab Notebooks/covid-19/validation/cov'

os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/validation/vir')
validation_vir = '/content/drive/My Drive/Colab Notebooks/covid-19/validation/vir'

os.mkdir('/content/drive/My Drive/Colab Notebooks/covid-19/validation/nor')
validation_nor = '/content/drive/My Drive/Colab Notebooks/covid-19/validation/nor'

for i in range(len(validation_files)):
    if validation_labels[i] == 'cov':
        shutil.copyfile(validation_files[i], os.path.join(validation_cov, validation_files[i].split('/')[-1]))
    elif validation_labels[i] == 'nor':
        shutil.copyfile(validation_files[i], os.path.join(validation_nor, validation_files[i].split('/')[-1]))
    else:
        shutil.copyfile(validation_files[i], os.path.join(validation_vir, validation_files[i].split('/')[-1]))

# %% [markdown]
# ## Data generator

# %%
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_DIM = (IMG_WIDTH, IMG_HEIGHT)
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.1, rotation_range=10,
                   width_shift_range=0.1, height_shift_range=0.1, shear_range=0.1, 
                   horizontal_flip=True, fill_mode='nearest')
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/covid-19/train', shuffle=True, 
                           batch_size=5, target_size=IMG_DIM, class_mode="categorical", classes=('cov', 'nor', 'vir'))
val_generator = val_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/covid-19/validation', 
                         batch_size=5, target_size=IMG_DIM, class_mode="categorical", classes=('cov', 'nor', 'vir'))
# Out:
# Found 3000 images belonging to 3 classes.
# Found 539 images belonging to 3 classes.

# %% [markdown]
# ### Model Definition

# %%
resnet = ResNet50(include_top=False, weights='imagenet', input_shape=(IMG_HEIGHT,IMG_WIDTH, 3))
x = resnet.output
x = Flatten()(x)
x = Dense(3, activation='softmax')(x)
model = Model(inputs=resnet.input, outputs=x)

model.compile(loss=categorical_crossentropy,
              optimizer=optimizers.Adam(lr=0.0001),
              metrics = [categorical_accuracy])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 518, 518, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 256, 256, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 256, 256, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 256, 256, 64) 0           conv1_bn[0][0]
# ...

# %% [markdown]
# ## Train 15 epochs, decrease learning rate from 1e-4 to 1e-6

# %%
history = model.fit(train_generator, 
           steps_per_epoch=600, 
           epochs=5,
           validation_data=val_generator, 
           validation_steps=108,
           verbose=1)
# Out:
# Epoch 1/5
# 600/600 [==============================] - 466s 776ms/step - loss: 1.3304 - categorical_accuracy: 0.8637 - val_loss: 4.2577 - val_categorical_accuracy: 0.2894
# Epoch 2/5
# 600/600 [==============================] - 274s 456ms/step - loss: 0.3594 - categorical_accuracy: 0.9283 - val_loss: 0.2213 - val_categorical_accuracy: 0.9369
# Epoch 3/5
# 600/600 [==============================] - 273s 455ms/step - loss: 0.3092 - categorical_accuracy: 0.9300 - val_loss: 0.2235 - val_categorical_accuracy: 0.9536
# Epoch 4/5
# 600/600 [==============================] - 274s 456ms/step - loss: 0.2381 - categorical_accuracy: 0.9430 - val_loss: 0.2464 - val_categorical_accuracy: 0.9295
# Epoch 5/5
# 600/600 [==============================] - 274s 457ms/step - loss: 0.2141 - categorical_accuracy: 0.9483 - val_loss: 0.2261 - val_categorical_accuracy: 0.9536

# %%
model.save('/content/drive/My Drive/Colab Notebooks/covid-19/resnet50_5epochs.h5')
model.compile(loss=categorical_crossentropy,
              optimizer=optimizers.Adam(lr=0.00001),
              metrics = [categorical_accuracy])
history = model.fit_generator(train_generator, 
                steps_per_epoch=600, 
                epochs=5,
                validation_data=val_generator, 
                validation_steps=108,
                verbose=1)
# Out:
# Epoch 1/5
# 600/600 [==============================] - 277s 461ms/step - loss: 0.1392 - categorical_accuracy: 0.9637 - val_loss: 0.1856 - val_categorical_accuracy: 0.9685
# Epoch 2/5
# 600/600 [==============================] - 276s 459ms/step - loss: 0.1026 - categorical_accuracy: 0.9703 - val_loss: 0.1750 - val_categorical_accuracy: 0.9740
# Epoch 3/5
# 600/600 [==============================] - 273s 456ms/step - loss: 0.0790 - categorical_accuracy: 0.9767 - val_loss: 0.1602 - val_categorical_accuracy: 0.9740
# Epoch 4/5
# 600/600 [==============================] - 274s 456ms/step - loss: 0.0754 - categorical_accuracy: 0.9777 - val_loss: 0.1653 - val_categorical_accuracy: 0.9740
# Epoch 5/5
# 600/600 [==============================] - 273s 455ms/step - loss: 0.0606 - categorical_accuracy: 0.9790 - val_loss: 0.1728 - val_categorical_accuracy: 0.9703

# %%
model.save('/content/drive/My Drive/Colab Notebooks/covid-19/resnet50_10epochs.h5')
model.compile(loss=categorical_crossentropy,
              optimizer=optimizers.Adam(lr=0.000001),
              metrics = [categorical_accuracy])
history = model.fit_generator(train_generator, 
                steps_per_epoch=600, 
                epochs=5,
                validation_data=val_generator, 
                validation_steps=108,
                verbose=1)
# Out:
# Epoch 1/5
# 600/600 [==============================] - 277s 462ms/step - loss: 0.0682 - categorical_accuracy: 0.9817 - val_loss: 0.1728 - val_categorical_accuracy: 0.9703
# Epoch 2/5
# 600/600 [==============================] - 274s 457ms/step - loss: 0.0528 - categorical_accuracy: 0.9863 - val_loss: 0.1732 - val_categorical_accuracy: 0.9703
# Epoch 3/5
# 600/600 [==============================] - 274s 457ms/step - loss: 0.0586 - categorical_accuracy: 0.9813 - val_loss: 0.1678 - val_categorical_accuracy: 0.9722
# Epoch 4/5
# 600/600 [==============================] - 275s 458ms/step - loss: 0.0531 - categorical_accuracy: 0.9827 - val_loss: 0.1655 - val_categorical_accuracy: 0.9722
# Epoch 5/5
# 600/600 [==============================] - 273s 456ms/step - loss: 0.0582 - categorical_accuracy: 0.9807 - val_loss: 0.1587 - val_categorical_accuracy: 0.9722

# %%
model.save('/content/drive/My Drive/Colab Notebooks/covid-19/resnet50_15epochs.h5')

# %% [markdown]
# ### Train-validation plot

# %%
acc = [0.8637, 0.9283, 0.9300, 0.9430, 0.9483, 0.9637, 0.9703, 0.9767, 0.9777, 0.9790, 0.9816, 0.9863, 0.9813, 0.9826, 0.9806]
val_acc = [0.2894, 0.9369, 0.9536, 0.9295, 0.9536, 0.9685, 0.9740, 0.9740, 0.9740, 0.9703, 0.9703, 0.9703, 0.9721, 0.9721, 0.9721]
loss = [1.3304, 0.3594, 0.3092, 0.2381, 0.2141, 0.1392, 0.1026, 0.0790, 0.0754, 0.0606, 0.0681, 0.0528, 0.0585, 0.0531, 0.0581]
val_loss = [4.2577, 0.2213, 0.2235, 0.2464, 0.2261, 0.1856, 0.1750, 0.1602, 0.1653, 0.1728, 0.1727, 0.1731, 0.1677, 0.1654, 0.1586]

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.savefig('file1.jpg')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.savefig('file2.jpg');

# %% [markdown]
# ## Confusion matrix on validation(test) set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        '/content/drive/My Drive/Colab Notebooks/covid-19/validation',
        target_size=(512, 512),
        shuffle = False,
        class_mode='categorical',
        classes=('cov', 'nor', 'vir'),
        batch_size=1)

filenames = test_generator.filenames
nb_samples = len(filenames)

predict = model.predict(test_generator,steps = nb_samples)
# Out:
# Found 539 images belonging to 3 classes.

# %%
test_generator.class_indices.keys()
# Out:
# dict_keys(['cov', 'nor', 'vir'])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns; sns.set()

predict_label = np.argmax(predict, axis=1)
true_label=test_generator.labels

mat = confusion_matrix(true_label, predict_label)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=['covid-19', 'normal', 'viral'], yticklabels=['covid-19', 'normal', 'viral'])
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# ## Attention map with Grad-CAM

# %%
class GradCAM:
	def __init__(self, model, classIdx, layerName=None):
		# store the model, the class index used to measure the class
		# activation map, and the layer to be used when visualizing
		# the class activation map
		self.model = model
		self.classIdx = classIdx
		self.layerName = layerName

		# if the layer name is None, attempt to automatically find
		# the target output layer
		if self.layerName is None:
			self.layerName = self.find_target_layer()

	def find_target_layer(self):
		# attempt to find the final convolutional layer in the network
		# by looping over the layers of the network in reverse order
		for layer in reversed(self.model.layers):
			# check to see if the layer has a 4D output
			if len(layer.output_shape) == 4:
				print(layer.name)
				return layer.name

		# otherwise, we could not find a 4D layer so the GradCAM
		# algorithm cannot be applied
		raise ValueError("Could not find 4D layer. Cannot apply GradCAM.")

	def compute_heatmap(self, image, eps=1e-8):
		# construct our gradient model by supplying (1) the inputs
		# to our pre-trained model, (2) the output of the (presumably)
		# final 4D layer in the network, and (3) the output of the
		# softmax activations from the model
		gradModel = Model(
			inputs=[self.model.inputs],
			outputs=[self.model.get_layer(self.layerName).output, 
				self.model.output])

		# record operations for automatic differentiation
		with tf.GradientTape() as tape:
			# cast the image tensor to a float-32 data type, pass the
			# image through the gradient model, and grab the loss
			# associated with the specific class index
			inputs = tf.cast(image, tf.float32)
			(convOutputs, predictions) = gradModel(inputs)
			loss = predictions[:, self.classIdx]

		# use automatic differentiation to compute the gradients
		grads = tape.gradient(loss, convOutputs)

		# compute the guided gradients
		castConvOutputs = tf.cast(convOutputs > 0, "float32")
		castGrads = tf.cast(grads > 0, "float32")
		guidedGrads = castConvOutputs * castGrads * grads

		# the convolution and guided gradients have a batch dimension
		# (which we don't need) so let's grab the volume itself and
		# discard the batch
		convOutputs = convOutputs[0]
		guidedGrads = guidedGrads[0]

		# compute the average of the gradient values, and using them
		# as weights, compute the ponderation of the filters with
		# respect to the weights
		weights = tf.reduce_mean(guidedGrads, axis=(0, 1))
		cam = tf.reduce_sum(tf.multiply(weights, convOutputs), axis=-1)

		# grab the spatial dimensions of the input image and resize
		# the output class activation map to match the input image
		# dimensions
		(w, h) = (image.shape[2], image.shape[1])
		heatmap = cv2.resize(cam.numpy(), (w, h))

		# normalize the heatmap such that all values lie in the range
		# [0, 1], scale the resulting values to the range [0, 255],
		# and then convert to an unsigned 8-bit integer
		numer = heatmap - np.min(heatmap)
		denom = (heatmap.max() - heatmap.min()) + eps
		heatmap = numer / denom
		heatmap = (heatmap * 255).astype("uint8")

		# return the resulting heatmap to the calling function
		return heatmap

	def overlay_heatmap(self, heatmap, image, alpha=0.5,
		colormap=cv2.COLORMAP_VIRIDIS):
		# apply the supplied color map to the heatmap and then
		# overlay the heatmap on the input image
		heatmap = cv2.applyColorMap(heatmap, colormap)
		output = cv2.addWeighted(image, alpha, heatmap, 1 - alpha, 0)

		# return a 2-tuple of the color mapped heatmap and the output,
		# overlaid image
		return (heatmap, output)

# %%
def cam_visualizer(file_path):
    print(file_path)
    src_img = cv2.imread(file_path)
    ori_img = src_img.astype(np.float)
    ori_img /= 255
    x = np.expand_dims(ori_img, axis=0)
    predict = model.predict(x)[0]
    index = np.argmax(predict)
    label = ['cov', 'nor', 'vir'][index]
    real_label = file_path.split('/')[-2]
    prob = predict[index]
    label = "{}: {:.2f}%".format(label, prob * 100)
    cam = GradCAM(model, index)
    heatmap = cam.compute_heatmap(x)

    heatmap = cv2.resize(heatmap, (512, 512))
    (heatmap, output) = cam.overlay_heatmap(heatmap, src_img, alpha=0.5)

    # draw the predicted label on the output image
    cv2.rectangle(output, (0, 0), (200, 35), (0, 0, 0), -1)
    cv2.putText(output, label, (10, 25), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    cv2.rectangle(src_img, (0, 0), (100, 35), (0, 0, 0), -1)
    cv2.putText(src_img, real_label, (10, 25), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
    # display the original image and resulting heatmap and output image
    # to our screen

    fig, ax = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(3*12,12))
    
    ax[0].imshow(src_img)
    ax[1].imshow(heatmap)
    ax[2].imshow(output)

# %%
cam_visualizer(glob('/content/drive/My Drive/Colab Notebooks/covid-19/validation/cov/*')[70])
# Out:
# /content/drive/My Drive/Colab Notebooks/covid-19/validation/cov/COVID-19 (94).png
# conv5_block3_out
